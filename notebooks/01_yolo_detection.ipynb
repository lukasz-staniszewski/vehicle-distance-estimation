# %% [markdown]
# # YOLO KITTI model training pipeline

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image
import os

# %%
os.chdir("/net/tscratch/people/plglukaszst/projects/vehicle-distance-estimation")

# %%
! python distance_estimation/detection/prepare_kitti_data.py

# %%
! python distance_estimation/detection/train_model.py

# %%
PATH = "experiments/detection/yolov8-kitti-detection/train5/results.png"
MODEL_PATH = "experiments/detection/yolov8-kitti-detection/train5/weights/best.onnx"

# %%
Image.open(PATH)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %% [markdown]
# # Example predictions

# %%
MODEL_PATH="/net/tscratch/people/plglukaszst/projects/vehicle-distance-estimation/experiments/detection/yolov8-kitti-detection/train5/weights/best.pt"
# MODEL_PATH="/net/tscratch/people/plglukaszst/projects/vehicle-distance-estimation/experiments/detection/yolov8-kitti-detection/train5/weights/best.onnx"

# %%
import torch
model = torch.load(MODEL_PATH)

# %%
from ultralytics import YOLO

# %%
model = YOLO(MODEL_PATH)

# %%
# Run batched inference on a list of images
results = model(['/net/tscratch/people/plglukaszst/projects/vehicle-distance-estimation/data/detection/testing/image_2/000003.png'])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    result.show()  # display to screen
    # result.save(filename='result.jpg')  # save to disk
# Out:
# 0: 224x640 3 Cars, 154.2ms
# Speed: 23.7ms preprocess, 154.2ms inference, 13.6ms postprocess per image at shape (1, 3, 224, 640)
# <PIL.Image.Image image mode=RGB size=1242x375>

# %%
boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0., 0.], device='cuda:0')
# conf: tensor([0.8958, 0.8876, 0.4748], device='cuda:0')
# data: tensor([[3.7763e+02, 1.8886e+02, 5.0096e+02, 2.6285e+02, 8.9584e-01, 0.0000e+00],
#         [6.0427e+02, 1.7990e+02, 6.4710e+02, 2.1677e+02, 8.8760e-01, 0.0000e+00],
#         [5.6763e+02, 1.7388e+02, 5.9288e+02, 1.9591e+02, 4.7475e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (375, 1242)
# shape: torch.Size([3, 6])
# xywh: tensor([[439.2940, 225.8555, 123.3312,  73.9825],
#         [625.6837, 198.3351,  42.8245,  36.8644],
#         [580.2557, 184.8951,  25.2504,  22.0272]], device='cuda:0')
# xywhn: tensor([[0.3537, 0.6023, 0.0993, 0.1973],
#         [0.5038, 0.5289, 0.0345, 0.0983],
#         [0.4672, 0.4931, 0.0203, 0.0587]], device='cuda:0')
# xyxy: tensor([[377.6284, 188.8642, 500.9596, 262.8467],
#         [604.2715, 179.9029, 647.0960, 216.7673],
# ...
